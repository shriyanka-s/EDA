# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\shris\\Documents\\NareshIT\\Python sessions'

# %% [markdown]
# ## Data Types

# %% [markdown]
# - int
# - float
# - bool
# - str
# - complex
# - range
# - list
# - tuple
# - dict
# - set
# - frozenset
# - bytes
# - bytearray
# - memoryview

# %% [markdown]
# ## Integer

# %%
number=100
type(number)
# Out:
# int

# %%
num1 = 100.23
type(num1)
# Out:
# float

# %%
print(10e1) #10*10
print(10e2) #10*100
print(10e3) #10*1000
# Out:
# 100.0
# 1000.0
# 10000.0

# %%
print(10e-1) #10/1
print(10e-2) #10/100
print(10e-3) #10/1000
# Out:
# 100.0
# 0.1
# 0.01

# %%
print(10e+1) #10*10
print(10e+2) #10*100
print(10e+3) #10*1000
# Out:
# 100.0
# 1000.0
# 10000.0

# %%
10e1==10e+1 #e means exponential
# Out:
# True

# %% [markdown]
# ## STRINGS

# %%
city='Hyderabad'
type(city)
# Out:
# str

# %%
"chennai"
# Out:
# 'chennai'

# %%
print("mumbAI")
# Out:
# mumbAI

# %%
print('hello    ')
# Out:
# hello

# %%
print('   hello')
# Out:
#    hello

# %%
print('hello')
# Out:
# hello

# %%
len('  hello  ')
# Out:
# 9

# %% [markdown]
# **Name not found error**
# - variable is not written before
# - and we are trying to use that
# - check wherther the variable is written before or not

# %%
str1 = 'python1'
str2 = "python2"
str1,str2
#print(str1,str2)
# Out:
# ('python1', 'python2')

# %%
print(str1,str2)
# Out:
# python1 python2

# %%
print("hiu 'dd'")
# Out:
# hiu 'dd'

# %% [markdown]
# ***Doc String***

# %%
print(""" hi 
 im a girl  
 thank you""")
# Out:
#  hi
#  im a girl
#  thank you

# %%
import random
random.random()
# Out:
# 0.36556341232830114

# %%
import math
math.pow(2,3)
# Out:
# 8.0

# %% [markdown]
# ## Boolean

# %%
bool (1 == 2)
# Out:
# False

# %%
n1=True
type(n1)
# Out:
# bool

# %%
true="True" #variable str data type
true= True #boolean
true = 10 #integer
true = 10.5 #float
false = true #variable
false
# Out:
# 10.5

# %%
n1={10,20,30}
type(n1)
# Out:
# set

# %%
d1={'num':1}
d1
type(d1)
# Out:
# dict
