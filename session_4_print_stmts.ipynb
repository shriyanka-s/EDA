# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\shris\\Documents\\NareshIT\\Python sessions'

# %%
a=10
b=20
print(a)
print(b)
# Out:
# 10
# 20

# %%
a,b
# Out:
# (10, 20)

# %%
print(a,b)
# Out:
# 10 20

# %%
a=366
b=234
c = a + b
print('sum of',a,'and',b,'is',c)
#sum of 10 and 20 is 30
# Out:
# sum of 366 and 234 is 600

# %%
name='pushpa'
age=100
city='hyderabad'
print('my name is',name,'im',age,' years old','and im from',city)
# Out:
# my name is pushpa im 100  years old and im from hyderabad

# %%
print('sum of {} and {} is {}'.format(a,b,c))
# Out:
# sum of 366 and 234 is 600

# %%
print('my name is {} im {} years old and im from {}'.format(name,age,city))
# Out:
# my name is pushpa im 100 years old and im from hyderabad

# %%
print(f"sum of {a} and {b} is {c}")
# Out:
# sum of 366 and 234 is 600

# %%
a = 100
b = 200
add = a + b
print(f'the addition of {a} and {b} is: {add}')
sub = a - b 
print(f'the subtraction of {a} and {b} is: {sub}')
multiply = a * b
print(f'the multiplication of {a} and {b} is: {multiply}')
div = a / b
print(f'the division of {a} and {b} is: {add}')
# Out:
# the addition of 100 and 200 is: 300
# the subtraction of 100 and 200 is: -100
# the multiplication of 100 and 200 is: 20000
# the division of 100 and 200 is: 300

# %%
a = 100
b = 200
print(f'the addition of {a} and {b} is: {a + b}')
print(f'the subtraction of {a} and {b} is: {a-b}')
print(f'the multiplication of {a} and {b} is: {a*b}')
print(f'the division of {a} and {b} is: {a/b}')
# Out:
# the addition of 100 and 200 is: 300
# the subtraction of 100 and 200 is: -100
# the multiplication of 100 and 200 is: 20000
# the division of 100 and 200 is: 0.5

# %%
a=21
b=32
c=47
avg = round((a+b+c)/3,3)
print(f'the average of {a} , {b} and {c} is {avg}')
# Out:
# the average of 21 , 32 and 47 is 33.333

# %%
round(.73)
# Out:
# 1
