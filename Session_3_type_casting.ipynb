# %%
number1 = 10 #int
number2 = 10.5 #float
name = 'NareshIT' #str
value = True #bool
fruits = ['Apple','banana','cherry'] #list
names=('ramesh','suresh','sathish') #tuple
age={20,22,24} #set
data={'Ramesh':20.'suresh':22,'sathish':24} #dict

# %%
n1='100'
n2='200'
n1+n2
# Out:
# '100200'

# %% [markdown]
# # Type Casting
# - covert one data type to another

# %%
num=0
float(num),str(num),bool(num)
# Out:
# (0.0, '0', False)

# %%
num1=10.5
int(num1),str(num1),bool(num1)
# Out:
# (10, '10.5', True)

# %%
s='abc'
bool(s)
# Out:
# True

# %%
print(int('10.5')) #10
print(float('10.5'))
print(bool('10.5'))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 print(int('10.5')) #10
#       2 print(float('10.5'))
#       3 print(bool('10.5'))
#
# ValueError: invalid literal for int() with base 10: '10.5'

# %%
n1= 10
print(n1)
# Out:
# 10

# %%
float('10.5'), int('10')
# Out:
# (10.5, 10)

# %%
float('10'),float('10.5')
# Out:
# (10.0, 10.5)

# %%
int('10')
int('10.5')
int(10)
int(10.5)
# Out:
# 10

# %%
bool('')
# Out:
# False

# %%
bool('0')
# Out:
# True

# %%
len('0')
# Out:
# 1

# %%
len('')
# Out:
# 0

# %%
#print(int('0.0'))
#error

# %%
print(float('0.0'))
print(bool('0.0'))
# Out:
# 0.0
# True

# %%
print(int(True))
print(float(True))
print(str(True))
print(bool(True))
#
print(int(False))
print(float(False))
print(str(False))
print(bool(False))
# Out:
# 1
# 1.0
# True
# True
# 0
# 0.0
# False
# False

# %%
str(True)
# Out:
# 'True'

# %%
int(float(10.5))
# Out:
# 10

# %%
n1='100'
n2='200'
n1+n2 #'100' + '200'
# Out:
# '100200'

# %%
n3 = int(n1)+ int(n2)
n3
# Out:
# 300

# %%
n1=int('100')
n2=int('200')
n1+n2
# Out:
# 300

# %%
n1='100.5'
n2='200'
n1+n2 #'100.5' +'200'
#i need 300.5. So, here
n1 = float('100.5')
n2 = int('200')
n1+n2
# Out:
# 300.5

# %% [markdown]
# **eval**

# %%
n1 = eval('100.5')
n2 = eval('200')
n1+n2
# Out:
# 300.5

# %%
type(n1)
# Out:
# float

# %%
 import os
os.getcwd()
# Out:
# 'C:\\Users\\shris\\Documents\\NareshIT\\Python sessions'

# %%
int(10.5)
# Out:
# 10

# %%
int('10')
# Out:
# 10
