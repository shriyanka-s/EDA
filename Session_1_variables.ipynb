# %%
a= 100
b= 200
c=a+b
c
# Out:
# 300

# %%
c=100
c = c+100
c
# Out:
# 200

# %%
c
# Out:
# 200

# %%
hello
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 hello
#
# NameError: name 'hello' is not defined

# %%
#hello

# %% [markdown]
# markdown mode

# %%
#code mode

# %% [markdown]
# # python
# ## python
# ### python

# %% [markdown]
# - hi
# - hyu
# - guh
# - kk

# %% [markdown]
# # Variables

# %% [markdown]
# - store the value
# - change the value

# %%
 area_of_triangles = 100

# %% [markdown]
# number=100 #w
# Number=200 #w
# NUMBER=300 #w
# number one=400 #f
# number_one=500 #w
# _=600 #w
# number@=700 #f
# if=800 #f
# else=900 #f

# %% [markdown]
# - Variables are case sensitive
#     -number and NUMBER
# - Variable can be capital and small letters
# - number as stating does not allow as variable
#     -123number
# - variables does not include spl characters
#     -number@
# - keywords or reserved words looks like green also not allowed as variables
#     ex: if else for True False elif def etc

# %%
num = 100
print(num)
# Out:
# 100

# %%
type(num)
# Out:
# int

# %%
sum = 100
sum
# Out:
# 100

# %%
Sum([100,200])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 Sum([100,200])
#
# NameError: name 'Sum' is not defined

# %%
min([400,200])
# Out:
# 200

# %%
print([1,2])
type([1,2])
# Out:
# [1, 2]
# list
