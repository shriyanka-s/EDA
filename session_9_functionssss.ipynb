# %%
def addition():
    num1 = 20
    num2 = 30
    add = num1 + num2
    print(f"Addition of {num1} and {num2} is {add}")
addition()
# Out:
# Addition of 20 and 30 is 50

# %%
def addition(num1,num2):
    num1 = eval(input("Enter first number: "))
    num2 = eval(input("Enter second number: "))
    add = num1 + num2
    print(f"Addition of {num1} and {num2} is {add}")
addition(1,1)
# Out:
# Enter first number:  4
# Enter second number:  6
# Addition of 4 and 6 is 10

# %%
import random

def addition1():
    num1 = random.randint(1,20)
    num2 = random.randint(1,20)
    add = num1 + num2
    print(f"Addition of {num1} and {num2} is {add}")
addition1()
# Out:
# Addition of 3 and 6 is 9

# %%
try :
    def addition3():
        num1 = eval(input("Enter first number: "))
        num2 = eval(input("Enter second number: "))
        add = num1 + num2222
        print(f"Addition of {num1} and {num2} is {add}")
  
except Exception as e:
    print(e)
addition3()
# Out:
# Enter first number:  2
# Enter second number:  3
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 10
#       8 except Exception as e:
#       9     print(e)
# ---> 10 addition3()
#
# Cell In[10], line 5, in addition3()
#       3 num1 = eval(input("Enter first number: "))
#       4 num2 = eval(input("Enter second number: "))
# ----> 5 add = num1 + num2222
#       6 print(f"Addition of {num1} and {num2} is {add}")
#
# NameError: name 'num2222' is not defined

# %%
def addition4():
    try :
        num1 = eval(input("Enter first number: "))
        num2 = eval(input("Enter second number: "))
        add = num1 + num2222
        print(f"Addition of {num1} and {num2} is {add}")
    except Exception as e:
        print(e)
addition4()
# Out:
# Enter first number:  3
# Enter second number:  4
# name 'num2222' is not defined

# %% [markdown]
# ## Function without arguments

# %%
def bill():
    bill = eval(input("Enter the bill: "))
    tip_per = eval(input("Enter the tip percentage: "))
    total_bill = bill +  (bill * tip_per)/100
    print(f"The total bill is {total_bill}")
bill()
# Out:
# Enter the bill:  50000
# Enter the tip percentage:  50
# The total bill is 75000.0

# %%
def area_triangle():
    height = eval(input("Enter height: "))
    breadth = eval(input("Enter breadth: "))
    triangle_area = 0.5 * height * breadth
    print("Area of triangle: ",triangle_area)
area_triangle()
# Out:
# Enter height:  5
# Enter breadth:  3
# Area of triangle:  7.5

# %%
def even_odd():
    num = eval(input("Enter the number: "))
    if num % 2 == 0:
        print("Number is even")
    else :
        print("Number is odd")
even_odd()
# Out:
# Enter the number:  34
# Number is even

# %%
def avg():
    num1 = eval(input("Enter num1: "))
    num2 = eval(input("Enter num2: "))
    num3 = eval(input("Enter num3: "))
    average = (num1 + num2 + num3)/3
    print("The average of three numbers is: ",average)
avg()
# Out:
# Enter num1:  3
# Enter num2:  5
# Enter num3:  7
# The average of three numbers is:  5.0

# %%
import random
def game_random():
    num_random = random.randint(1,10)
    print(num_random)
    num = eval(input("Enter the num:"))
    
    if num == num_random:
        print("You won")
    else:
        print(f"You lost because your num is {num} and random num is {num_random}")
game_random()
# Out:
# 3
# Enter the num: 3
# You won

# %%
def addition():
    """
    doc string addition
    """
    num1=eval(input('enter num1:'))
    num2=eval(input('enter num2:'))
    add=num1+num2
    print(f'the addition of {num1} and {num2} is:{add}')

# %%
addition()
# Out:
# enter num1: 2
# enter num2: 3
# the addition of 2 and 3 is:5

# %% [markdown]
# ## Function with arguments

# %%
def addition1(num1,num2):

    print("Num1:",num1)
    print("Num2:",num2)
    add = num1 + num2
    print(f'the addition of {num1} and {num2} is:{add}')

# %%
addition1(100,200)
# Out:
# Num1: 100
# Num2: 200
# the addition of 100 and 200 is:300

# %%
def avg2(a,b,c):

    average = a + b + c/3
    print(f"the avergae of {a}, {b}, {c} is : {average}")
avg2(3,5,8)
# Out:
# the avergae of 3, 5, 8 is : 10.666666666666666

# %%
def greet(name,age):
    print(f"Hello my name is {name} and age is {age} ")
greet('Python',45)
# Out:
# Hello my name is Rama and age is 45

# %%
def greet2(name,/,age):
    print(f"Hello my name is {name} and age is {age} ")
# Out:
# Hello my name is Rama and age is 45

# %%
greet2('Python',45)
# Out:
# Hello my name is Python and age is 45

# %%
greet2(name='Python',45)
# Out:
#   Cell In[23], line 1
#     greet2(name='Python',45)
#                            ^
# SyntaxError: positional argument follows keyword argument

# %%
greet2('python',age=39)
# Out:
# Hello my name is python and age is 39

# %%
greet2(name='python',age = 74)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 greet2(name='python',age = 74)
#
# TypeError: greet2() got some positional-only arguments passed as keyword arguments: 'name'

# %%
def add8():
    b=200
    c=300
    addition=a+b+c  # addition= a+b+c  No error
    print(f"the addition of {a},{b} and {c} is {addition}")
a=2000
add8()
# Out:
# the addition of 2000,200 and 300 is 2500

# %%
def add8():
    b=200
    c=300
    addition=a+b+c  # error
    a=5000
    print(f"the addition of {a},{b} and {c} is {addition}")
a=2000
add8()
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[2], line 8
#       6     print(f"the addition of {a},{b} and {c} is {addition}")
#       7 a=2000
# ----> 8 add8()
#
# Cell In[2], line 4, in add8()
#       2 b=200
#       3 c=300
# ----> 4 addition=a+b+c  # error
#       5 a=5000
#       6 print(f"the addition of {a},{b} and {c} is {addition}")
#
# UnboundLocalError: cannot access local variable 'a' where it is not associated with a value

# %% [markdown]
# ## RETURN STMTS

# %%
def average(a,b,c):
    add = a+b+c
    avg = round(add/3,2)
    print(f'The average of {a}, {b} and {c} is: {avg}')
    return( avg, add)

foo = average(4,2,6)
# Out:
# The average of 4, 2 and 6 is: 4.0

# %%
foo
# Out:
# (4.0, 12)

# %% [markdown]
# ## Function in function

# %%
def greet1():
    print("Good morning")

# %%
def greet2():
    print("Good night")

# %%
greet1()
greet2()
# Out:
# Good morning
# Good night

# %%
def greet1():
    print("Good morning")
    greet2()

def greet2():
    print("Good night")
    greet1()

# %%
greet1().
# Out:
#   Cell In[38], line 1
#     greet1().
#              ^
# SyntaxError: invalid syntax

# %%
def greet11():
    def greet22():
        print("good night")
        #greet1 1()
    print("good morning")
    greet22()
greet11()
# Out:
# good morning
# good night

# %%
def addd(a,b):
    print("Add: ",a+b)
def mull(a,b):
        print("Multiply: ",a*b)
addd(4,5)
mull(8,3)
# Out:
# Add:  9
# Multiply:  24

# %%
def maths():
    addd(483,832)
    mull(243,23)
maths()
# Out:
# Add:  1315
# Multiply:  5589

# %%
def bigmaths(a,b):
    def mathss():
        def ad():
            print("Add: ",a+b)
        def mu():
            print("Multiply: ",a*b)
        ad()
        mu()
    mathss()
bigmaths(10,20)
# Out:
# Add:  30
# Multiply:  200

# %%
def number(n):
    if n==0:
        return
    print(n)
    number(n-1)
number(6)
# Out:
# 6
# 5
# 4
# 3
# 2
# 1

# %%
#factorial
6! = 6*5*4*3*2*1

# %%
def fact(n):
    if n==0:
        return(1)
    result = n * fact(n-1)
    return result
    
fact(6)
# Out:
# 720

# %%
def fact(n):
    if n==0:
        return(1)
    else: 
        result = n * fact(n-1)
        return result
    
fact(6)

# %%
def fact(n):
    if n == 0 :
        return 1
    else :
        return n * fact(n-1)

fact(5)
# Out:
# 120
